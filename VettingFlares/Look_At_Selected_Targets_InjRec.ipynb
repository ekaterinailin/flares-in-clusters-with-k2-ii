# %%
from altaipony.injrecanalysis import plot_heatmap, tile_up_injection_recovery


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
paths = ! ls Injection_Recovery_on_Selected_Targets/injrec/
ids = [p.split("_")[1][:-4] for p in paths]
ids = list(set(ids))

# %%
ID = ids[0]
df = pd.DataFrame()
for p in paths:
    if ID in p:
        df = df.append(pd.read_csv("Injection_Recovery_on_Selected_Targets/injrec/"+p), ignore_index=True)
print(df.shape)
bins = 16
dff, val = tile_up_injection_recovery(df, "recovery_probability",ampl_bins=bins, dur_bins=bins,)
plot_heatmap(dff, val, ID=ID);
dff, val = tile_up_injection_recovery(df, "ed_ratio",ampl_bins=bins, dur_bins=bins,)
plot_heatmap(dff, val, ID=ID);
# Out:
# (10104, 14)

# %%
14300/160
# Out:
# 89.375
